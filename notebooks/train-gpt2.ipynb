# %%
# !git clone 'https://github.com/aakashvardhan/s21-gpt2.git'
# Out:
# Cloning into 's21-gpt2'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 12 (delta 1), reused 11 (delta 0), pack-reused 0
# Receiving objects: 100% (12/12), 503.42 KiB | 1.62 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd s21-gpt2
# Out:
# /content/s21-gpt2

# %%
# !pip

# %%
# !python train_gpt2.py
# Out:
# Traceback (most recent call last):
#   File "/content/s21-gpt2/train_gpt2.py", line 6, in <module>
#     import tiktoken
# ModuleNotFoundError: No module named 'tiktoken'
